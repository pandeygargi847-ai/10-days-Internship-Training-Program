# %% [markdown]
# <a href="https://colab.research.google.com/github/pandeygargi847-ai/10-days-Internship-Training-Program/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
. bimport pandas as pd

data = {
    "Student_ID": [101,102,103,104,105,106,107,108,109,110,
                   111,112,113,114,115,116,117,118,119,120],

    "Name": ["Aman","Neha","Rahul","Priya","Karan",
             "Simran","Mohit","Anjali","Vikas","Pooja",
             "Rohit","Sneha","Arjun","Riya","Deepak",
             "Muskan","Yash","Komal","Abhishek","Nisha"],

    "Gender": ["Male","Female","Male","Female","Male",
               "Female","Male","Female","Male","Female",
               "Male","Female","Male","Female","Male",
               "Female","Male","Female","Male","Female"],

    "Age": [20,21,19,22,20,21,20,19,22,20,
            21,20,23,19,22,20,21,22,20,19],

    "Department": ["CSE","IT","ECE","CSE","IT",
                   "CSE","ECE","IT","CSE","ECE",
                   "IT","CSE","ECE","IT","CSE",
                   "ECE","IT","CSE","ECE","IT"],

    "Semester": [4,4,2,6,4,6,2,4,8,6,
                 2,8,6,4,8,2,6,4,8,2],

    "Marks": [85,92,78,95,67,88,72,91,81,76,
              69,94,73,89,97,66,82,90,79,84],

    "Attendance": [92,95,85,97,78,90,82,98,88,84,
                   80,96,83,91,99,76,89,94,87,92],

    "CGPA": [8.5,9.2,7.8,9.5,6.9,
             8.8,7.2,9.1,8.1,7.6,
             7.0,9.4,7.4,8.9,9.8,
             6.8,8.2,9.0,7.9,8.4],

    "City": ["Delhi","Lucknow","Noida","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi",
             "Noida","Lucknow","Delhi","Jaipur","Delhi"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# ...

# %%
df
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# ...

# %%
df.duplicated().sum()  #returns boolean series indicating whether each row is a duplicate of a previous now, since true is treated as 1 and false as 0, summing gives the total number of duplicated rows in the entire
# Out:
# np.int64(0)

# %%
df.duplicated() #it checks the dupliacte rows in a pandas dataframe
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df.isnull().sum() #in pandas is used to quickly check how many missing values each column in a dataframe has
# Out:
# Student_ID    0
# Name          0
# Gender        0
# Age           0
# Department    0
# Semester      0
# Marks         0
# Attendance    0
# CGPA          0
# City          0
# dtype: int64

# %%
df.drop("City", axis=1, inplace=True) # Removes the 'City' column from the DataFrame
# df.drop() is used to remove specified labels from rows or columns.
# axis=1 indicates that a column should be dropped (axis=0 is for rows).
# inplace=True modifies the DataFrame directly without needing re-assignment.
# The 'errors' parameter can be set to 'ignore' to prevent an error if the column doesn't exist.
df # Displays the DataFrame after the operation.
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# ...
